# %% [markdown]
# ## **Fire Heatmap of South America**
# -----
# #### SDS 210 - Programming with Spatial Data
#
# *Author: Isabelle Bartholet*
#
# *Date: May 2025*
#
#
# ### **Content**
#
# 1. Load important packages and call map key via function check_map_key()
# 2. Fetch the Data via function fetch_data()
# 3. convert to gdf
# 4. Create Heatmap

# %%
import requests
import pandas as pd
import geopandas as gpd
import time
import matplotlib.pyplot as plt
import folium
import contextily
import cmcrameri


from cartopy import crs as ccrs
from geodatasets import get_path
